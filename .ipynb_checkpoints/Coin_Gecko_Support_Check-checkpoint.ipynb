# %%
import pandas as pd

# %%
target_html_1 = '''<html>
<div _ngcontent-eqq-c21="" class="market-list list-view" data-etoro-locale-ns="discoverMarketResultsList"><!----><div _ngcontent-eqq-c21="" class="list-row-title"><div _ngcontent-eqq-c21="" automation-id="discover-market-results-symbol-head" class="list-row-title-cell pointer sort"> Market </div><div _ngcontent-eqq-c21="" automation-id="discover-market-results-change-head" class="list-row-title-cell pointer sort change"> Change </div><div _ngcontent-eqq-c21="" automation-id="discover-market-results-date-head" class="list-row-title-cell sort pointer change"><span _ngcontent-eqq-c21="" class="date">1D</span><div _ngcontent-eqq-c21="" class="resolution-arrows"><span _ngcontent-eqq-c21="" class="resolution-arrow-up"></span><span _ngcontent-eqq-c21="" class="resolution-arrow-down"></span></div></div><div _ngcontent-eqq-c21="" class="list-row-title-cell mobile-off buy-sell-column"><div _ngcontent-eqq-c21="" class="row-title-label">Sell</div><div _ngcontent-eqq-c21="" class="space-gap"></div><div _ngcontent-eqq-c21="" class="row-title-label">Buy</div></div><div _ngcontent-eqq-c21="" class="list-row-title-cell weeks"><div _ngcontent-eqq-c21="" automation-id="watchlist-list-title-range" class="row-title-label">52W Range</div></div><div _ngcontent-eqq-c21="" class="list-row-title-cell sentiment"><div _ngcontent-eqq-c21="" class="row-title-label">Sentiment</div></div><a _ngcontent-eqq-c21="" class="button-standard button-blue done pointer"><span _ngcontent-eqq-c21="" class="button-icon sprite"></span><span _ngcontent-eqq-c21="" class="done-button-text">discoverMarketResultsList.done</span></a></div><!----><!----><!----><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/btc"><div _ngcontent-eqq-c34="" class="avatar-img-wrap" style="background-color: rgb(240, 175, 50);"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100000/100000_ F0AF32_F7F7F7.svg" alt="Bitcoin"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">BTC</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">Bitcoin</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-352.24</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-1.71%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">20269.<span class="after-decimal">67</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">20738.<span class="after-decimal">28</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">17401.73</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">68724.00</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 5.94268%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-0" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-0"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/eth"><div _ngcontent-eqq-c34="" class="avatar-img-wrap" style="background-color: rgb(44, 44, 44);"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100001/100001_2C2C2C_F7F7F7.svg" alt="Ethereum"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">ETH</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">Ethereum</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-31.4188</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-2.83%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">1080.<span class="after-decimal">0722</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">1105.<span class="after-decimal">2054</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">870.17</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">4819.48</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 5.5408%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-1" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-1"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/bch"><div _ngcontent-eqq-c34="" class="avatar-img-wrap" style="background-color: rgb(241, 176, 51);"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100002/100002_F1B033_F7F7F7.svg" alt="Bitcoin Cash"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">BCH</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">Bitcoin Cash</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-3.10</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-2.65%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">114.<span class="after-decimal">00</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">116.<span class="after-decimal">63</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">105.51</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">796.34</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 1.35642%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-2" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-2"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/xrp"><div _ngcontent-eqq-c34="" class="avatar-img-wrap" style="background-color: rgb(44, 44, 44);"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100003/100003_2C2C2C_F7F7F7.svg" alt="XRP"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">XRP</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">XRP</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.00462</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-1.43%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">31934</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label negative-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">32656</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">0.28</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">1.40</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 3.3868%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-3" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-3"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/dash"><div _ngcontent-eqq-c34="" class="avatar-img-wrap" style="background-color: rgb(50, 133, 194);"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100004/100004_3285C2_F7F7F7.svg" alt="Dash"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">DASH</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">Dash</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-1.48</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-3.17%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">45.<span class="after-decimal">23</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">46.<span class="after-decimal">39</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">38.04</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">280.70</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 3.12967%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-4" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-4"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/ltc"><div _ngcontent-eqq-c34="" class="avatar-img-wrap" style="background-color: rgb(54, 96, 153);"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100005/100005_366099_F7F7F7.svg" alt="Litecoin"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">LTC</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">Litecoin</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-1.48</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-2.80%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">51.<span class="after-decimal">33</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">52.<span class="after-decimal">55</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">39.88</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">292.39</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 4.70956%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-5" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-5"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/etc"><div _ngcontent-eqq-c34="" class="avatar-img-wrap" style="background-color: rgb(23, 136, 68);"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100007/100007_178844_F7F7F7.svg" alt="Ethereum Classic"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">ETC</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">Ethereum Classic</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.6043</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-3.78%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">15.<span class="after-decimal">3727</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">15.<span class="after-decimal">7463</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">12.32</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">77.30</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 4.88714%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-6" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-6"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/api3"><div _ngcontent-eqq-c34="" class="avatar-img-wrap"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100008/150x150.png" alt="API3"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">API3</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">API3</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.059</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-3.70%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label disabled positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">1.<span class="after-decimal">536</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">1.<span class="after-decimal">581</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">1.01</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">9.36</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 6.49395%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-7" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-7"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/cro"><div _ngcontent-eqq-c34="" class="avatar-img-wrap"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100009/150x150.png" alt="Cronos"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">CRO</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">Cronos</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.00159</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-1.38%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label disabled negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">11344</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">11627</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">0.09</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">0.95</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 3.37968%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-8" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-8"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/imx"><div _ngcontent-eqq-c34="" class="avatar-img-wrap"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100016/150x150.png" alt="Immutable X"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">IMX</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">Immutable X</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.0222</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-2.84%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label disabled positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">7604</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">7801</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">0.63</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">9.31</div></div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 1.64042%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-eqq-c39=""><!----><div _ngcontent-eqq-c39="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-eqq-c39="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-eqq-c39="" class="bar-wrap"><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-eqq-c39="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-eqq-c28="" _nghost-eqq-c29=""><!----><et-trade-item-card-action _ngcontent-eqq-c21="" _nghost-eqq-c29="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-eqq-c21="" _nghost-eqq-c30=""><et-select _ngcontent-eqq-c30="" class="no-arrow ng-tns-c24-9" _nghost-eqq-c24=""><div _ngcontent-eqq-c24="" class="ng-tns-c24-9"><et-select-header _ngcontent-eqq-c30="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-eqq-c21="" automation-id="discover-market-results-row" _nghost-eqq-c28="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-eqq-c28="" automation-id="watchlist-grid-instruments-list" _nghost-eqq-c33="" class="ng-star-inserted"><div _ngcontent-eqq-c33="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-eqq-c33="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-eqq-c34=""><a _ngcontent-eqq-c34="" class="card-avatar-wrap" href="/markets/ada"><div _ngcontent-eqq-c34="" class="avatar-img-wrap" style="background-color: rgb(98, 153, 254);"><img _ngcontent-eqq-c34="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100017/100017_6299FE_F7F7F7.svg" alt="Cardano"><!----></div><div _ngcontent-eqq-c34="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-eqq-c34="" automation-id="trade-item-name" class="symbol">ADA</div><div _ngcontent-eqq-c34="" automation-id="trade-item-full-name" class="name">Cardano</div></div></a></et-card-avatar><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted negative"><!----><!----><div _ngcontent-eqq-c33="" class="change-items"><b _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.01133</b><div _ngcontent-eqq-c33="" class="instrument-num"><span _ngcontent-eqq-c33="" class="arrow-sign"></span>(-2.38%)</div></div></div><!----><div _ngcontent-eqq-c33="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-eqq-c33="" _nghost-eqq-c36=""><div _ngcontent-eqq-c36="" class="sparklines"><et-canvas-chart _ngcontent-eqq-c36="" class="fedeOut fadeIn" _nghost-eqq-c41=""><!----><canvas _ngcontent-eqq-c41="" class="ng-star-inserted" width="184" height="35" style="width: 184px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-eqq-c33="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-eqq-c33="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-eqq-c37=""><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-eqq-c40="" class="trade-button-title">S</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">46501</span></div></div></et-buy-sell-button><div _ngcontent-eqq-c37="" class="space-gap"></div><et-buy-sell-button _ngcontent-eqq-c37="" _nghost-eqq-c40=""><div _ngcontent-eqq-c40="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-eqq-c40="" class="trade-button-title">B</div><div _ngcontent-eqq-c40="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">47622</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-eqq-c33="" class="instrument-cell" _nghost-eqq-c38=""><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-eqq-c38="" class="price-range"><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-min" class="low">0.40</div><div _ngcontent-eqq-c38="" automation-id="fifty-two-weeks-range-max" class="high">3
" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-eqq-c25=""><div _ngcontent-eqq-c25="" class="header-text"></div><i _ngcontent-eqq-c25="" class="icon-arrow-down"></i><i _ngcontent-eqq-c25="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><!----><!----></div>
</html>'''

# %%
# Reads excel, converts to dataframe

df_coin_etoro = pd.read_excel('CoinEtoro.xlsx')

df_coin_gecko = pd.read_excel('CoinGecko.xlsx')

# %%
# Extracts cols in Etoro, converts them to list

df_etoro_symbol = df_coin_etoro.loc[:, 'Coin(Etoro)']
df_etoro_name = df_coin_etoro.loc[:, 'Coin(Etoro) Name']
etoro_symbol_lst = df_etoro_symbol.tolist()
etoro_name_lst = df_etoro_name.tolist()

# %%
# Extracts cols in Gecko, converts them to list

df_gecko_symbol = df_coin_gecko.loc[:, 'symbol']
df_gecko_name = df_coin_gecko.loc[:, 'name']
gecko_symbol_lst = df_gecko_symbol.tolist()
gecko_name_lst = df_gecko_name.tolist()

# %%
# Performs the coin gecko support checks
#
# If etoro symbol is exactly equivalent to gecko symbol, stores only(or all) the exact matches
# Otherwise (no exact match), if etoro symbol is a substring of gecko symbol, stores all the substring matches

has_gecko_support = []
gecko_ref_map = []

# Iterates through [etoro_symbol_lst]
for i in range(len(etoro_symbol_lst)):
    
    # Extracts this current etoro symbol to be checked
    etoro_symbol = etoro_symbol_lst[i]
    
    # Initializes them as No/None
    has_gecko_support.append('No')
    gecko_ref_map.append({})
    
    # Temp var to store has exact match
    has_exact_match = False
    
    # Iterates through [gecko_symbol_lst], looks for exact matches 
    for j in range(len(gecko_symbol_lst)):
        
        # Extacrs this current gecko symbol to check for support
        gecko_symbol = gecko_symbol_lst[j]
        
        # Has exact match
        if str(etoro_symbol).lower() == str(gecko_symbol).lower():
            has_gecko_support[i] = ('Yes')
            
            # Checks if there's multiple same keys
            if gecko_symbol_lst[j].upper() in gecko_ref_map[i]:
                # If so, appends the gecko name value
                gecko_ref_map[i][gecko_symbol_lst[j].upper()].append(gecko_name_lst[j])
            else:
                # If not, init a new gecko symbol-name pair as a key-value pair
                gecko_ref_map[i][gecko_symbol_lst[j].upper()] = [gecko_name_lst[j]]
            
            has_exact_match = True
            
    # Iterate through [gecko_symbol_lst] only if there is no exact match, mark the [has_gecko_support] as 'No'
    if (not has_exact_match):
        for k in range(len(gecko_symbol_lst)):
            
            # Extracts current gecko symbol to check for support
            gecko_symbol = gecko_symbol_lst[k]
        
            if str(etoro_symbol).lower() in str(gecko_symbol).lower():
                has_gecko_support[i] = ('No')
                
                # Checks if there's multiple same keys
                if gecko_symbol_lst[k].upper() in gecko_ref_map[i]:
                    # If so, appends the gecko name value
                    gecko_ref_map[i][gecko_symbol_lst[k].upper()].append(gecko_name_lst[k])
                else:
                    # If not, init a new gecko symbol-name pair as a key-value pair
                    gecko_ref_map[i][gecko_symbol_lst[k].upper()] = [gecko_name_lst[k]]

# %%
# Creates dataframe, export as excel

result_data = {
    'Coin(Etoro) Symbol' : etoro_symbol_lst,
    'Coin(Etoro) Name' : etoro_name_lst,
    'Has Gecko Support' : has_gecko_support,
    'Gecko Coin Reference (Symbol : [Name])' : gecko_ref_map
}

df_results = pd.DataFrame(result_data)

df_results.to_csv('C:/Users/ZH128895/Work/CoinGeckoSupportCheck/CoinGeckoSupportCheckResults/CoinGeckoSupportCheck_6-21-456.csv')
